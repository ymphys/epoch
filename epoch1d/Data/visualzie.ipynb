# %%
import sys
sys.path.append('../SDF/utilities')
import sdf_helper as sh
import numpy as np
import matplotlib.pyplot as plt
from concurrent.futures import ProcessPoolExecutor

# %%
# load data
data = sh.getdata(50,verbose=False)

# %%
# list variables
print("Variables in the data file:")
sh.list_variables(data)
# Out:
# Variables in the data file:
# CPU_split_Left <class 'sdf.BlockPlainVariable'> [9]
# CPU_split_Right <class 'sdf.BlockPlainVariable'> [9]
# CPUs_Current_rank <class 'sdf.BlockPlainVariable'> [0]
# CPUs_Original_rank <class 'sdf.BlockPlainVariable'> [8]
# Current_Jx <class 'sdf.BlockPlainVariable'> [400]
# Derived_Average_Particle_Energy <class 'sdf.BlockPlainVariable'> [400]
# Derived_Charge_Density <class 'sdf.BlockPlainVariable'> [400]
# Derived_Number_Density <class 'sdf.BlockPlainVariable'> [400]
# Derived_Number_Density_Left <class 'sdf.BlockPlainVariable'> [400]
# Derived_Number_Density_Right <class 'sdf.BlockPlainVariable'> [400]
# Derived_Temperature <class 'sdf.BlockPlainVariable'> [400]
# Derived_Temperature_Left <class 'sdf.BlockPlainVariable'> [400]
# Derived_Temperature_Right <class 'sdf.BlockPlainVariable'> [400]
# Electric_Field_Ex <class 'sdf.BlockPlainVariable'> [400]
# Electric_Field_Ey <class 'sdf.BlockPlainVariable'> [400]
# Electric_Field_Ez <class 'sdf.BlockPlainVariable'> [400]
# Grid_CPU_split_Left <class 'sdf.BlockPlainMesh'> [10]
# Grid_CPU_split_Left_mid <class 'sdf.BlockPlainMesh'> [9]
# Grid_CPU_split_Right <class 'sdf.BlockPlainMesh'> [10]
# Grid_CPU_split_Right_mid <class 'sdf.BlockPlainMesh'> [9]
# Grid_CPUs_Original_rank <class 'sdf.BlockPlainMesh'> [9]
# Grid_CPUs_Original_rank_mid <class 'sdf.BlockPlainMesh'> [8]
# Grid_Grid <class 'sdf.BlockPlainMesh'> [401]
# Grid_Grid_mid <class 'sdf.BlockPlainMesh'> [400]
# Grid_Particles_Left <class 'sdf.BlockPointMesh'> [1600]
# Grid_Particles_Right <class 'sdf.BlockPointMesh'> [1600]
# Grid_x_px_Left <class 'sdf.BlockPlainMesh'> [400, 200]
# Grid_x_px_Left_mid <class 'sdf.BlockPlainMesh'> [399, 199]
# Grid_x_px_Right <class 'sdf.BlockPlainMesh'> [400, 200]
# Grid_x_px_Right_mid <class 'sdf.BlockPlainMesh'> [399, 199]
# Magnetic_Field_Bx <class 'sdf.BlockPlainVariable'> [400]
# Magnetic_Field_By <class 'sdf.BlockPlainVariable'> [400]
# Magnetic_Field_Bz <class 'sdf.BlockPlainVariable'> [400]
# Particles_Px_Left <class 'sdf.BlockPointVariable'> [1600]
# Particles_Px_Right <class 'sdf.BlockPointVariable'> [1600]
# Wall_time <class 'sdf.BlockConstant'> [1]
# dist_fn_x_px_Left <class 'sdf.BlockPlainVariable'> [400, 200]
# dist_fn_x_px_Right <class 'sdf.BlockPlainVariable'> [400, 200]

# %%
# plot the data
plt.ion()
sh.plot1d(data.Particles_Px_Left, 'r.',ms=2,yscale=1)
sh.oplot1d(data.Particles_Px_Right, 'b.',ms=2,yscale=1)
plt.ylim([-6e-24,6e-24])
# Out:
# (-6e-24, 6e-24)

# %%
# 循环读取并绘图保存
for n in range(0, 101):
    try:
        # 读取数据
        data = sh.getdata(n,verbose=False)

        # 清空当前图像，避免叠加
        plt.clf()
        plt.ion()

        # 绘图
        sh.plot1d(data.Particles_Px_Left, 'r.', ms=2, yscale=1)
        sh.oplot1d(data.Particles_Px_Right, 'b.', ms=2, yscale=1)
        plt.ylim([-6e-24, 6e-24])

        # 保存图像
        plt.savefig(f"./Data/2stream/{n:04d}.png", dpi=300)  # 用4位数编号
        print(f"Saved frame {n}")

    except Exception as e:
        print(f"Error at frame {n}: {e}")
