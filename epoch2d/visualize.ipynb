# %%
import sys
sys.path.append('../SDF/utilities')
import sdf_helper as sh
import numpy as np
import matplotlib.pyplot as plt

# %%
# load data
data = sh.getdata('./Data/0000.sdf')
# Out:
# Reading file ./Data/0000.sdf
# t() = time
# x(501, 501) = grid
# y(501, 501) = grid
# xc(500, 500) = grid_mid
# yc(500, 500) = grid_mid

# %%
# list variables
print("Variables in the data file:")
sh.list_variables(data)
# Out:
# Variables in the data file:
# CPUs_Current_rank <class 'sdf.BlockPlainVariable'> [0, 0]
# CPUs_Original_rank <class 'sdf.BlockPlainVariable'> [2, 4]
# Derived_Number_Density <class 'sdf.BlockPlainVariable'> [500, 500]
# Derived_Number_Density_Electron <class 'sdf.BlockPlainVariable'> [500, 500]
# Derived_Number_Density_Proton <class 'sdf.BlockPlainVariable'> [500, 500]
# Grid_CPUs_Original_rank <class 'sdf.BlockPlainMesh'> [3, 5]
# Grid_CPUs_Original_rank_mid <class 'sdf.BlockPlainMesh'> [2, 4]
# Grid_Grid <class 'sdf.BlockPlainMesh'> [501, 501]
# Grid_Grid_mid <class 'sdf.BlockPlainMesh'> [500, 500]
# Wall_time <class 'sdf.BlockConstant'> [1]

# %%
# plot the data
plt.ion()
sh.plot_auto(data.Derived_Number_Density_Electron)

# %%
plt.ion()
sh.plot_auto(data.Derived_Number_Density_Proton)
