# %%
import sys
sys.path.append('../SDF/utilities')
import sdf_helper as sh
import numpy as np
import matplotlib.pyplot as plt

# %%
# load data
data = sh.getdata('./Data/0007.sdf')
# Out:
# Reading file ./Data/0007.sdf
# t() = time
# ey(200,) = ey
# x(201,) = grid
# xc(200,) = grid_mid

# %%
# list variables
print("Variables in the data file:")
sh.list_variables(data)
# Out:
# Variables in the data file:
# CPUs_Current_rank <class 'sdf.BlockPlainVariable'> [0]
# CPUs_Original_rank <class 'sdf.BlockPlainVariable'> [8]
# Electric_Field_Ey <class 'sdf.BlockPlainVariable'> [200]
# Grid_CPUs_Original_rank <class 'sdf.BlockPlainMesh'> [9]
# Grid_CPUs_Original_rank_mid <class 'sdf.BlockPlainMesh'> [8]
# Grid_Grid <class 'sdf.BlockPlainMesh'> [201]
# Grid_Grid_mid <class 'sdf.BlockPlainMesh'> [200]
# Wall_time <class 'sdf.BlockConstant'> [1]

# %%
# plot the data
plt.ion()
plt.plot(xc,ey)

# %%
plt.ion()
sh.plot_auto(data.Electric_Field_Ey)
